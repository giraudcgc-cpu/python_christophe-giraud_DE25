# %% [markdown]
# # Welcome to the testing place

# %% [markdown]
# ##### Here you will first find the last way Kokchun asked me to test called "NEW WAY TO SHOW TESTS". I have not tested everything this way and below you will find the Manual Testing Zone where you can test.

# %%
from circle import Circle
from rectangle import Rectangle
from circle import Circle

# %%
### NEW WAY TO SHOW TESTS ###
r1 = rectangle1 = Rectangle(0,0,3,1)
r2 = rectangle2 = Rectangle(0,0,10,4)
r3 = rectangle3 = Rectangle(0,0,4,4)
r4 = rectangle4 = Rectangle(0,0,1,3)
c1 = circle1 = Circle(0,0,1)
c2 = circle2 = Circle(0,0,2)
c3 = circle3 = Circle(0,0,3)
c4 = circle4 = Circle(0,0,1)
print("-" * 10, "Checking the repr", "-" * 10)
print(f"{c1 = }")
print(f"{c2 = }")
print(f"{r1 = }")
print(f"{r2 = }") 
print("-" * 10, "Checking string", "-" * 10)
print(f"c1:{c1}")
print(f"r3:{r3}")
print("-" * 10, "area", "-" * 10)
print(f"{c1.area = }")
print(f"{c1.area_rounded = }")
print(f"{r2.area = }")
print("-" * 10, "perimeter", "-" * 10)
print(f"{c1.perimeter = }")
print(f"{c1.perimeter_rounded = }")
print(f"{r2.perimeter = }")
print("-" * 10, "is_unit_cirle?", "-" * 10)
print(f"{c1.is_unit_circle() = }")
print(f"{c3.is_unit_circle() = }")
print("-" * 10, "radius", "-" * 10)
# c10 = Circle(2,2,-10) raises a ValueError
try:
    c10 = Circle(2,2,-10)
except ValueError as err:
    print(err)

#c11 = Circle(1,1, True) raises a TypeError
try:
    c11 = Circle(1,1, True)
except TypeError as err:
    print(err)
print("-" * 10, "is_square?", "-" * 10)
print(f"{r2.is_square() = }")
print(f"{r3.is_square() = }")
print("-" * 10, "moving the center", "-" * 10)
print(f"{c3 = }")
print(f"{c3.translate(-8,1)= }")
print(f"{r3 = }")
print(f"{r3.translate(4,4)= }")
print("-" * 10, "comparisons", "-" * 10)
print(f"{r1 == r2 = }")
print(f"{r1 == r4 = }")
print(f"{c1 == c4 = }")
print(f"{r1 >= r4 = }")
print(f"{c2 >= c3 = }")
print(f"{r1 <= r3 = }")
print(f"{r1 <= r4 = }")
print(f"{r1 < r4 = }")
print(f"{r1 < r2 = }")
print(f"{c1 < c2 = }")
print(f"{c1 < c3 = }")
print(f"{c3 > c2 = }")
print(f"{c1 > c4 = }")
print("-" * 10, "comparisons between shapes", "-" * 10)
c9 = Circle(3,3,3)
rect9 = Rectangle(3,3,3,3)
print(f"{c9 == rect9 = }")
print(f"c9 area is: {c9.area} or rounded at {c9.area_rounded}")
print(f"rect9 area is: {rect9.area}")
print("-" *10, "More comparisons with shape, area, perimeter", "-" *10)
print("=== With 2 circles: ===")
c1 = Circle(0,0,5)
c2 = Circle(3,4,7)
print(c1.compare_with(c2))
print("=== With 2 rectangles: ===")
r1 = Rectangle(2,2,4,1)
r2 = Rectangle(2,2,6,1)
print(r2.compare_with(r1))
print("=== With 1 circle and 1 rectangle: ===")
c1 = Circle(0,0,5)
r1 = Rectangle(2,2,4,1)
print(c1.compare_with(r1))
# Out:
# ---------- Checking the repr ----------
# c1 = Circle(x=0, y=0, radius=1)
# c2 = Circle(x=0, y=0, radius=2)
# r1 = Rectangle(x=0, y=0, length=3, width=1)
# r2 = Rectangle(x=0, y=0, length=10, width=4)
# ---------- Checking string ----------
# c1:This circle has center coordinates x=0, y=0 and a radius of 1
# r3:Point (0, 0) is the center of the rectangle with length 4 and width 4
# ---------- area ----------
# c1.area = 3.141592653589793
# c1.area_rounded = 3.14
# r2.area = 40
# ---------- perimeter ----------
# c1.perimeter = 6.283185307179586
# c1.perimeter_rounded = 6.28
# r2.perimeter = 28
# ---------- is_unit_cirle? ----------
# c1.is_unit_circle() = True
# c3.is_unit_circle() = False
# ---------- radius ----------
# radius must be a positive number (> 0)
# Invalid bool, radius must be a positive number, int or float
# ---------- is_square? ----------
# r2.is_square() = False
# r3.is_square() = True
# ---------- moving the center ----------
# c3 = Circle(x=0, y=0, radius=3)
# ...

# %% [markdown]
# # Manual Testing zone

# %% [markdown]
# #### Rectangle: enter numbers between the below brackets

# %%
try:
    rect = Rectangle("0", 0, 6, 2)
    print(rect)
except TypeError as err:
    print(err)
# Out:
# Invalid '0'! Value must be a number (integer or float), not str

# %% [markdown]
# #### Tested by Kokchun

# %%
# Circle(Rectangle,0,1) #Kokchun tested
rect9 == circle2
# Out:
# False

# %%
circle2.radius=1 #Kokchun tested
circle2.translate(5,-2)
circle2
# Out:
# Circle(x=5, y=-2, radius=1)

# %%
circle2.translate(-5,2).is_unit_circle() #Kokchun tested
# Out:
# True

# %% [markdown]
# #### Circle: coordinates and radius

# %%
try:
    c1 = Circle(0, 0, -1)
except ValueError as err:
    print(err)
# Out:
# radius must be a positive number (> 0)

# %%
circle3 = Circle(radius=3)
print(circle3)
# Out:
# This circle has center coordinates x=0, y=0 and a radius of 3

# %% [markdown]
# #### Calculating the area

# %%
print(f"{c1.area = }")
# Out:
# c1.area = 78.53981633974483

# %%
c2 = Circle(0,0,2)
c2.area
# Out:
# 12.566370614359172

# %%
c9.area, c9.area_rounded
# Out:
# (28.274333882308138, 28.27)

# %%
print(f"{rect.area = }")  #if not defined, run2nd block in the perimeter with rect = rect = Rectangle(0,0,1,3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(f"{rect.area = }")  #if not defined, run2nd block in the perimeter with rect = rect = Rectangle(0,0,1,3)
#
# NameError: name 'rect' is not defined

# %% [markdown]
# #### Calculating the perimeter/circumference

# %%
c1 = Circle(0,0,9)
c1.perimeter
print(f"has a perimeter of {c1.perimeter}")
print(f"rounded at {c1.perimeter_rounded}")
# Out:
# has a perimeter of 56.548667764616276
# rounded at 56.55

# %%
rect = Rectangle(0,0,1,3)
rect6 = Rectangle(0,0,3,1)         
print(f"Has a perimeter of {rect.perimeter}")
rect == rect6
# Out:
# Has a perimeter of 8
# True

# %% [markdown]
# #### Moving the center

# %%
rect
#rect.translate(2,3)

# %%
c3 = Circle(6,6, 2)
# Enter a number for x and y to move them
c3.translate(-3,-3)

# %%
c3.radius =1
c3.translate(5,-4).is_unit_circle()

# %%
print(c1)
c1.translate(True, 5)
#try-except below

# %%
try:
    c1.translate(True, 5)
except TypeError as err:
    print(err)

# %% [markdown]
# #### Check the repr

# %%
c3

# %%
rect1 = Rectangle(4,4,12,2)
rect1

# %% [markdown]
# #### Check the string

# %%
c1 = Circle(0,0,1)
c3 = Circle(0,0,2)
print(f"c3: {c3}")

# %%
str(c3)

# %%
rect = Rectangle(0, 0, 6, 2)
print(rect)

# %% [markdown]
# #### is_unit_circle?

# %%
c4 = Circle(0,0,2)
c5 = Circle(0,0,1)
c4.is_unit_circle(), c5.is_unit_circle()

# %% [markdown]
# #### is_square?

# %%
rect1 = Rectangle(0,0,6,3)
rect2 = Rectangle(0,0,4,4)

# %%
rect1 = Rectangle(0,0, 6, 3).is_square()
rect1

# %%
print(rect2.is_square())

# %% [markdown]
# #### Check Operators Overload

# %%
r1 == r2

# %%
c1 = Circle(0,0,1)
c2 = Circle(0,0,3)
c3 = Circle(0,0,2)
c4 = Circle(0,0,1)

print(f"{c1 = }")
print(f"{c2 = }")
print(f"{c1 == c4 = }")

# %%
r1 = rectangle1 = Rectangle(0,0,3,1)
r2 = rectangle2 = Rectangle(0,0,10,4)
r1 > r2, r1 < r2

# %%
# Checking greater than with > or less than <
c1 < c2, c2 > c3, c3 > c1

# %%
c1 = Circle(0,0,1)
c2 = Circle(0,0,3)
c3 = Circle(0,0,2)
c4 = Circle(0,0,1)

c4 <= c2

# %%
# Comparison of types
try:
    c4 <= "c2"
except TypeError as err:
    print(err)

# %%
# Checking greater or equal to with >=
c1 >= c2, c3 >= c4, c1 >= c4

# %%
r1 = rectangle1 = Rectangle(0,0,3,1)
r2 = rectangle2 = Rectangle(0,0,10,4)
r3 = rectangle3 = Rectangle(0,0,4,4)
r4 = rectangle4 = Rectangle(0,0,1,3)

r1 <= r4, r1 <= r2

# %%
r3 >= r2, r1 >= r4

# %%
# comparing circle to rectangle via the area
c9 = Circle(3,3,2)
rect9 = Rectangle(2,2,4,1)
print(c9 == rect9)

print(f"c9 has an area of {c9.area_rounded}")
print(f"rect9 had an area of {rect9.area}")

# %%
c100 = Circle(0,0,3) #Kokchuns test
#c100(radius=True)

try:
    Circle(radius=True)
except TypeError as err:
    print(err)

# %%
c10 = Circle(2, 2, -10)
#see below for try-except

# %%
try:
    c10 = Circle(2,2,-10)
except ValueError as err:
    print(err)

# %%
c101 = Circle(0,0,3)
print(c101)

# %%
c101.radius = True
c101 #Kokchun tested 
# scroll down for try-except

# %%
try:
    c101.radius = True
except TypeError as err:
    print(err)

# %%
c1 > True 
# scroll down for tr-except

# %%
try:
    c1 > True
except TypeError as err:
    print(err)

# %%
r1 == c1

# %%
# new test 
c1 = Circle(0,0,1)
c2 = Circle(0,0,3)
c3 = Circle(0,0,2)
c4 = Circle(0,0,1)
c2.radius=1
print(c1)

# %%
# new test: compare_with
c20 = Circle(3,3,3)
c21 = Circle(6,6,6)
r20 = Rectangle(2,2,2,2)
r21 = Rectangle(4,4,4,4)
print(c20.compare_with(r20))

# %%
c1.translate(True, 4)
print(c1)
# see below for try-except

# %%
try:
    c1.translate(True, 4)
except TypeError as err:
    print(err)

# %%
c3 = Circle(0, 0, 5)
c3.translate(3, 4)

# %%
r1 = Rectangle(1, 2, 4, 3)      ## ex for dosct rwect
r1.x = 10        # ← works! validated!
r1

# %%
r1 = Rectangle(1, 2, 4, 3)
r1.y = True
r1

# %%
# Comparing rectangles
r1 = Rectangle(0, 0, 4, 3)
r2 = Rectangle(5, 5, 6, 2)

print(r1.compare_with(r2))

# %%
# Comparing circle and rectangle
c1 = Circle(0, 0, 3) 
print(r1.compare_with(c1))

# %%
# Ignoring the centre
Circle(0,0,5) == Circle(100,100,5)

# %%
# ignoring the centre
Circle(0,0,5) == Circle(0,0,3)

# %%
r1 = Rectangle(0, 0, 4, 3) #last check 
r1.perimeter_rounded

# %%
r1 = Rectangle(0, 0, 4, 3)   # area = 12
r2 = Rectangle(0, 0, 5, 5)   # area = 25
c1 = Circle(0, 0, 2)

# %%
print(r1 >= r2)  
print(r2 >= r1)  
print(r1 >= c1)  
print(c1 >= r1)
