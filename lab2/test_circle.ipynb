# %%
from circle import Circle
import matplotlib.pyplot as plt

# %% [markdown]
# #### Circle: Enter the center coordinates and radius

# %%
# Enter in the brackets(x_value, y_value, radius_value) separated with comma, int|float only
c1 = Circle(0, 0, 1)

# %% [markdown]
# #### Calculating the area

# %%
print(f"{c1.area = }")
# Out:
# c1.area = 3.141592653589793

# %%
c2 = Circle(0,0,2)
c2.area
# Out:
# 12.566370614359172

# %% [markdown]
# #### Calculating the perimeter/circumference

# %%
# Checking the perimeter/circumference | In the brackets, enter 3 nbers (included zero for x and y), int|float to define (x, y, radius_length)
c1 = Circle(0,0,6)
c1.perimeter_is
print(f"has a perimeter of {c1.perimeter_is}")
print(f"rounded at {c1.perimeter_rounded}")
# Out:
# has a perimeter of 37.69911184307752
# rounded at 37.7

# %% [markdown]
# #### Moving the center

# %%
# Define a cirle with (x_value, y_value, radius_value). 
c3 = Circle(3,3, 3)
# Enter a number for x and y to move them
c3.translate(1,1)
# Out:
# 'moves its center 1 points in x and 1 points in y. New center:(4,4)'

# %% [markdown]
# #### Check the repr

# %%
# Type the variable name and execute 
c3
# Out:
# Circle, radius= 3, center at x=4, y=4

# %% [markdown]
# #### Check the string

# %%
print(c3)
# Out:
# This circle has center coordinates x=4, y=4 and a radius of 3

# %% [markdown]
# #### is a unit circle?

# %%
# A unit circle is centered at (0,0) and has a radius of 1
c4 = Circle(0,1,1)
c4.unit_circle()
# Out:
# False

# %% [markdown]
# #### Check Operators Overload

# %%
c1 = Circle(0,0,1)
c2 = Circle(1,0,3)
c3 = Circle(1,0,2)
c4 = Circle(0,0,1)

# %%
# Check equality with == 
c1 == c4

# %%
# Checking greater than with > or <
c1 < c2, c2 > c4, c3 > c4,

# %%
# Checking less or equal to with <=
c2 <= c4 # to check again

# %%
# Checking greater or equal to with >=
c1 >= c2, c3 >= c4, c1 >= c4
