# %%
from circle import Circle
import matplotlib.pyplot as plt
from rectangle import Rectangle
from circle import Circle

# %%
#NEW WAY TO SHOW TESTS
r1 = rectangle1 = Rectangle(0,0,3,1)
r2 = rectangle2 = Rectangle(0,0,10,4)
r3 = rectangle3 = Rectangle(0,0,4,4)
r4 = rectangle4 = Rectangle(0,0,1,3)
c1 = circle1 = Circle(0,0,1)
c2 = circle2 = Circle(0,0,2)
c3 = circle3 = Circle(0,0,3)
c4 = circle4 = Circle(0,0,1)

print("-" * 10, "Checking the repr", "-" * 10)
print(f"{c1 = }")
print(f"{c2 = }")
print(f"{c3 = }")
print(f"{c4 = }")
print(f"{r1 = }")
print(f"{r2 = }")
print(f"{r3 = }")
print(f"{r4 = }") 

print("-" * 10, "Checking string", "-" * 10)
print(f"c1:{c1}")
print(f"r3:{r3}")

print("-" * 10, "area", "-" * 10)
print(f"{c1.area = }")
print(f"{c1.area_rounded = }")
print(f"{r2.area = }")

print("-" * 10, "perimeter", "-" * 10)
print(f"{c1.perimeter_is = }")
print(f"{c1.perimeter_rounded = }")
print(f"{r2.perimeter_is = }")

print("-" * 10, "is unit_cirle?", "-" * 10)
print(f"{c1.is_unit_circle() = }")
print(f"{c3.is_unit_circle() = }")

print("-" * 10, "radius", "-" * 10)
print(f"{c1.is_unit_circle() = }")

try:
    c10 = Circle(2,2,-10)
except ValueError as err:
    print(err)




print("-" * 10, "is_square?", "-" * 10)
print(f"{r1.is_square() = }")
print(f"{r2.is_square() = }")
print(f"{r3.is_square() = }")

print("-" * 10, "moving the center", "-" * 10)
print(f"{c3 = }")
print(f"{c3.translate(-8,1)= }")
print(f"{r3 = }")
print(f"{c3.translate(2,1)= }")

print("-" * 10, "comparisons", "-" * 10)
print(f"{r1 == r2 = }")
print(f"{r1 == r4 = }")
print(f"{c1 == c4 = }")
print(f"{r1 >= r4 = }")
print(f"{c2 >= c3 = }")
print(f"{r1 <= r3 = }")
print(f"{r1 <= r4 = }")
print(f"{r1 < r4 = }")
print(f"{r1 < r2 = }")
print(f"{c1 < c2 = }")
print(f"{c1 < c3 = }")
print(f"{c3 > c2 = }")
print(f"{c1 > c4 = }")

print("-" * 10, "comparisons between shapes", "-" * 10)
c9 = Circle(3,3,3)
rect9 = Rectangle(3,3,3,3)
print(f"{c9 == rect9 = }")
print(c9.area)
print(rect9.area)
# Out:
# ---------- Checking the repr ----------
# c1 = Circle(x=0, y=0, radius=1)
# c2 = Circle(x=0, y=0, radius=2)
# c3 = Circle(x=0, y=0, radius=3)
# c4 = Circle(x=0, y=0, radius=1)
# r1 = Rectangle(x=0, y=0, length=3, width=1)
# r2 = Rectangle(x=0, y=0, length=10, width=4)
# r3 = Rectangle(x=0, y=0, length=4, width=4)
# r4 = Rectangle(x=0, y=0, length=1, width=3)
# ---------- Checking string ----------
# c1:This circle has center coordinates x=0, y=0 and a radius of 1
# r3:Point (0, 0) is the center of the rectangle with length 4 and width 4
# ---------- area ----------
# c1.area = 3.141592653589793
# c1.area_rounded = 3.14
# r2.area = 40
# ---------- perimeter ----------
# c1.perimeter_is = 6.283185307179586
# c1.perimeter_rounded = 6.28
# r2.perimeter_is = 28
# ---------- is unit_cirle? ----------
# c1.is_unit_circle() = True
# c3.is_unit_circle() = False
# ---------- radius ----------
# c1.is_unit_circle() = True
# radius must be a positive number (> 0)
# ---------- is_square? ----------
# r1.is_square() = False
# r2.is_square() = False
# r3.is_square() = True
# ---------- moving the center ----------
# c3 = Circle(x=0, y=0, radius=3)
# c3.translate(-8,1)= Circle(x=-8, y=1, radius=3)
# r3 = Rectangle(x=0, y=0, length=4, width=4)
# c3.translate(2,1)= Circle(x=-6, y=2, radius=3)
# ---------- comparisons ----------
# r1 == r2 = False
# r1 == r4 = True
# c1 == c4 = True
# r1 >= r4 = True
# c2 >= c3 = False
# r1 <= r3 = True
# r1 <= r4 = True
# r1 < r4 = False
# r1 < r2 = True
# c1 < c2 = True
# c1 < c3 = True
# c3 > c2 = True
# c1 > c4 = False
# ---------- comparisons between shapes ----------
# c9 == rect9 = False
# 28.274333882308138
# 9

# %%
# Circle(Rectangle,0,1) #Kokchun tested
rect9 == circle2
# Out:
# False

# %%
circle2.radius=1 #Kokchun tested
circle2.translate(5,-2)
circle2
# Out:
# Circle(x=5, y=-2, radius=1)

# %%
circle2.translate(-5,2).is_unit_circle() #Kokchun tested
# Out:
# True

# %% [markdown]
# #### Circle: Enter the center coordinates and radius

# %%
try:
    c1 = Circle(0, 0, -1)
except ValueError as err:
    print(err)
# Out:
# radius must be a positive number (> 0)

# %%
circle3 = Circle(radius=3)
print(circle3)
# Out:
# This circle has center coordinates x=0, y=0 and a radius of 3

# %% [markdown]
# #### Calculating the area

# %%
print(f"{c1.area = }")
# Out:
# c1.area = 3.141592653589793

# %%
c2 = Circle(0,0,2)
c2.area
# Out:
# 12.566370614359172

# %%
c9.area, c9.area_rounded
# Out:
# (28.274333882308138, 28.27)

# %% [markdown]
# #### Calculating the perimeter/circumference

# %%
c1 = Circle(0,0,9)
c1.perimeter_is
print(f"has a perimeter of {c1.perimeter_is}")
print(f"rounded at {c1.perimeter_rounded}")
# Out:
# has a perimeter of 56.548667764616276
# rounded at 56.55

# %% [markdown]
# #### Moving the center

# %%
c3 = Circle(6,6, 2)
# Enter a number for x and y to move them
c3.translate(-3,-3)
# Out:
# Circle(x=3, y=3, radius=2)

# %%
c3.radius =1
c3.translate(5,-4).is_unit_circle()
# Out:
# False

# %%
print(c1)
c1.translate(True, 5)
# Out:
# This circle has center coordinates x=0, y=0 and a radius of 9
# Circle(x=1, y=5, radius=9)

# %% [markdown]
# #### Check the repr

# %%
c3
# Out:
# Circle(x=8, y=-1, radius=1)

# %% [markdown]
# #### Check the string

# %%
c1 = Circle(0,0,1)
c3 = Circle(0,0,2)
print(f"c3: {c3}")
# Out:
# c3: This circle has center coordinates x=0, y=0 and a radius of 2

# %%
str(c3)
# Out:
# 'This circle has center coordinates x=0, y=0 and a radius of 2'

# %% [markdown]
# #### is a unit circle?

# %%
c4 = Circle(0,0,2)
c5 = Circle(0,0,1)
c4.is_unit_circle(), c5.is_unit_circle()
# Out:
# (False, True)

# %% [markdown]
# #### Check Operators Overload

# %%
c1 = Circle(0,0,1)
c2 = Circle(0,0,3)
c3 = Circle(0,0,2)
c4 = Circle(0,0,1)

print(f"{c1 = }")
print(f"{c2 = }")
print(f"{c1 == c4 = }")
# Out:
# c1 = Circle(x=0, y=0, radius=1)
# c2 = Circle(x=0, y=0, radius=3)
# c1 == c4 = True

# %%
# Checking greater than with > or less than <
c1 < c2, c2 > c3, c3 > c1
# Out:
# (True, True, True)

# %%
c1 = Circle(0,0,1)
c2 = Circle(0,0,3)
c3 = Circle(0,0,2)
c4 = Circle(0,0,1)

c4 <= c2
# Out:
# True

# %%
# Comparison of types
try:
    c4 <= "c2"
except TypeError as err:
    print(err)
# Out:
# Invalid comparison of types. Cannot compare Circle with str

# %%
# Checking greater or equal to with >=
c1 >= c2, c3 >= c4, c1 >= c4
# Out:
# (False, True, True)

# %%
# comparing circle to rectangle via the area
c9 = Circle(3,3,2)
rect9 = Rectangle(2,2,4,1)
print(c9 == rect9)

print(f"c9 has an area of {c9.area_rounded}")
print(f"rect9 had an area of {rect9.area}")
# Out:
# False
# c9 has an area of 12.57
# rect9 had an area of 4

# %%
c100 = Circle(0,0,3) #Kokchuns test
#c100(radius=True)

try:
    Circle(radius=True)
except TypeError as err:
    print(err)
# Out:
# Invalid bool, radius must be a positive number, int or float

# %% [markdown]
# #### Error Handling

# %%
try:
    c10 = Circle(2,2,-10)
except ValueError as err:
    print(err)
# Out:
# radius must be a positive number (> 0)

# %%
c101 = Circle(0,0,3)
print(c101)
###NEED TO FIX IT should not show radius=True!!! #Kokchuns test
# boolean, check discord Zineb screenshots
# Out:
# This circle has center coordinates x=0, y=0 and a radius of 3

# %%
c101.radius = True
c101 #Kokchun tested 
# scroll down for try-except
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 c101.radius = True
#       2 c101 #Kokchun tested
#       3 # scroll down for try-except
#
# File c:\Users\girau\Documents\github\python_christophe-giraud_DE25\lab2\circle.py:22, in Circle.radius(self, value)
#      19 @radius.setter
#      20 def radius(self, value) -> Number:
#      21     if isinstance(value, bool):
# ---> 22         raise TypeError(f"Invalid {type(value).__name__}, radius must be a positive number, int or float")
#      23     validate_number(value)
#      24     validate_positive(value, "radius")
#
# TypeError: Invalid bool, radius must be a positive number, int or float

# %%
try:
    c101.radius = True
except TypeError as err:
    print(err)

# %%
c1 > True 
# scroll down for tr-except
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 c1 > True
#       2 # scroll down for tr-except
#
# File c:\Users\girau\Documents\github\python_christophe-giraud_DE25\lab2\shape.py:66, in Shape.__gt__(self, other)
#      65 def __gt__(self, other) -> Number:
# ---> 66     return self.area > self._area_of(other)
#
# File c:\Users\girau\Documents\github\python_christophe-giraud_DE25\lab2\shape.py:52, in Shape._area_of(self, other)
#      50     return other.area
#      51 if isinstance(other, bool):
# ---> 52     raise TypeError(f"Invalid comparison {type(self).__name__} with boolean")
#      53 if isinstance(other, Number):
#      54     # in matplotlib int become float, will need it for pi
#      55     return float(other)
#
# TypeError: Invalid comparison Circle with boolean

# %%
try:
    c1 > True
except TypeError as err:
    print(err)
# Out:
# Invalid comparison Circle with boolean

# %%
r1 == c1
# Out:
# False

# %%
#New tests no idea
c1 = Circle(0,0,1)
c2 = Circle(0,0,3)
c3 = Circle(0,0,2)
c4 = Circle(0,0,1)
c2.radius=1
print(c1)
