# %%
from circle import Circle
import matplotlib.pyplot as plt

# %% [markdown]
# #### Circle: Enter the center coordinates and radius

# %%
# Enter in the brackets(x=value, y=value, radius=value) separated with comma, int|float only
c1 = Circle(0, 0, 1)

# %% [markdown]
# #### Calculating the area

# %%
print(f"{c1.area = }")
# Out:
# c1.area = 3.141592653589793

# %%
c2 = Circle(0,0, 7)
c2.area
# Out:
# 153.93804002589985

# %% [markdown]
# #### Moving the center

# %%
# Define a cirle with (x_value, y_value, radius_value). 
c3 = Circle(3,3, 2)
# Enter a number for x and y to move them
c3.translate(1,1)
# Out:
# 'moves its center 1 points in x and 1 points in y. New center:(4,4)'

# %% [markdown]
# #### Check the repr

# %%
# Type the variable name and execute 
c3
# Out:
# Circle, radius= 2, center at x=4, y=4

# %% [markdown]
# #### Check the string

# %%
print(c3)
# Out:
# This circle has center coordinates x=4, y=4 and a radius of 2

# %% [markdown]
# #### Comparison tests
