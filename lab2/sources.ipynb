# %% [markdown]
# # Sources

# %% [markdown]
# I got helped for/from:
#
# - import math found at https://www.w3schools.com/python/ref_math_pi.asp
# - pi from https://www.w3schools.com/python/ref_math_pi.asp
# - Lectures like oop_fundamentals documentation for dosctrings
# - Lectures to use utils that we used when working with vectors
# - Stuga and in particular to test with Kokchun, Zineb
# - Chatgpt
# - Talked with some of my fellow students like Miranda (abstractmethod) taht I did nto use as such and Johnny who mentioned
#
# Took also from below but won't be used to publish:
#
# matplotlib: googled how to create a circle with matplotlib python
# https://www.geeksforgeeks.org/python/how-to-draw-a-circle-using-matplotlib-in-python/
# For the rectangle, I used https://www.youtube.com/watch?v=T8RXMRlRoRg
