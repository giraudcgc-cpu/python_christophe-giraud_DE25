# %% [markdown]
# # Sources

# %% [markdown]
# # matplotlib: googled how to create a circle with matplotlib python
# # or https://www.geeksforgeeks.org/python/how-to-draw-a-circle-using-matplotlib-in-python/
# # For the rectangle, I used https://www.youtube.com/watch?v=T8RXMRlRoRg
# # import math found at https://www.w3schools.com/python/ref_math_pi.asp
# # https://www.youtube.com/watch?v=T8RXMRlRoRg
# # took pie from https://www.w3schools.com/python/ref_math_pi.asp
# add the rest before sending
# stuga
# oop_fundamentals documentation
